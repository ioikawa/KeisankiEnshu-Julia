# %% [markdown]
# # Markdown
#
# Jupyter NotebookではMarkdownとよばれる軽量マークアップ言語がサポートされている．
#
# ## Markdownタグによる記述例
# セルをMarkdownモードに設定する．タグを用いて太字で記述できる．
#
# `**太字**` と書いて `shift+enter`を押す．
#
# > **太字**
#
# Jupyter NotebookにおけるMarkdown記法に関しては，以下のリンクを参照．
# * https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
#
# ## よく使うタグ
#
# ### 見出し
# ```
# # Headings 1
# ## Headings 1.1
# ## Headings 1.2
# ### Headings 1.2.1
# ### Headings 1.2.2
# ### Headings 1.2.3
# ```
#
# > # Headings 1
# > ## Headings 1.1
# > ## Headings 1.2
# > ### Headings 1.2.1
# > ### Headings 1.2.2
# > ### Headings 1.2.3
#
# ### 箇条書き (itemize)
# ```
# - One
#     - Item 1
#       - A
#       - B
#       - C
# - Tow
#     - Item 2
# ```
# > - One
# >    - Item 1
# >      - A
# >      - B
# >      - C
# > - Tow
# >    - Item 2
#
# ## 文字装飾
#
# ```
# - **Boldface**
# - _Italic_
# - ~~Strikethrough~~
# - `Code span`
# ```
# > - **Boldface**
# > - _Italic_
# > - ~~Strikethrough~~
# > - `Code span`
# > -
# ## コードブロック
#
# <raw>
# ``` <br>
# x = 10 <br>
# @show x^2 <br>
# ```
# </raw>
#
# > ```
# > x = 10
# > @show x^2
# > ```
#
#
# ## 引用ブロック
# 公式ドキュメントの[冒頭](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)から文章を拝借して引用してみよう． 文頭に `>` を書くことで引用ブロックで表示される．
# ```
# >Text can be added to Jupyter Notebooks using Markdown cells. You can change the cell type to Markdown by using the Cell menu, the toolbar, or the key shortcut m. Markdown is a popular markup language that is a superset of HTML.
# ```
#
# >Text can be added to Jupyter Notebooks using Markdown cells. You can change the cell type to Markdown by using the Cell menu, the toolbar, or the key shortcut m. Markdown is a popular markup language that is a superset of HTML.

# %% [markdown]
# ## LaTeXによる数式記述
# 文章中のLaTeX数式は `$...$` で記述できる．例えば，`$\frac{a}{b}$` は
# $ \frac{a}{b} $
# となる．
#
# 別行立ての数式は `$$...$$` と書けばよい．
# ```tex
# $$ \sin(\alpha\pm \beta) = \sin\alpha\cos\beta \pm \cos\alpha\sin\beta $$
# ```
# > $$ \sin(\alpha\pm \beta) = \sin\alpha\cos\beta \pm \cos\alpha\sin\beta $$
#
# `\[...\]`は対応していないことに注意．
#
# 複数行の数式は aligned 環境を用いる．
# $$ \begin{aligned}
#  e^{\frac{i\pi}{4}}
#  &= \cos\frac{i\pi}{4} + i \sin \frac{i\pi}{4} \\
#  &= \frac{1}{\sqrt{2}}\left(1 + i \right)
# \end{aligned} $$

# %% [markdown]
# ## HTMLタグの使用
# Markdown記法とともに，HTMLタグも使用できる．
# ```
# - <b>boldface</b>
# - <span style="color:blue">blue</span>
# ```
#
# > - <b>boldface</b>
# > - <span style="color:blue">blue</span>
