# %% [markdown]
# #

# %% [markdown]
# # JuliaとJupyter Notebookの準備
#
# ## WindowsにおけるJuliaの起動
#
# はじめに，Julia (v1.10.3) を起動する．
#
# プロンプト `julia>` にコマンド等を記述して実行することができる．
# <br>
# この状態をREPLモードと呼ぶ．
#
#
#
#
# ## IJuliaパッケージのインストール
#
# `]`キーで**pkgモード**に入る．
#
# ```
# pkg> add IJulia  <ENTER>
# ```
# を実行し，しばらく待つ．ログ（経過出力）の最後に
# ```
# 15 dependencies successfully precompiled in 29 seconds
# ```
# のように表示されれば正常にIJuliaがインストールされている．
#
#
# <div class="alert alert-block alert-warning">
# もし，`fail` や `ERROR` 等の文字列が表示されている場合はエラーが発生（＝インストールに失敗）しているので，再度， `add Julia` を実行する．もしそれでもエラーが発生する場合は教員・TAに報告してください．
# </div>
#
#
# ## Juliaカーネルの登録
# Jupyter notebookへJuliaカーネルを登録する．
#
# ```
# juila> using IJulia; notebook(detached=true)
# ```
#
# カーネルの登録は１度だけ行う．
#
# <div class="alert alert-block alert-info">
# UbuntuではIJuliaパッケージはインストール済みである．
# ただし，REPLモードで下記コマンドを１度だけ実行する必要がある．
#
# ```
# using IJulia
# IJulia.installkernel("Julia MyProjectEnv", "--project=$(Base.active_project())")
# notebook(detached=true)
# ```
#
# </div>
#
# ## Jupyter Notebookの起動
# Jupyter Notebookアプリを起動する．
# デフォルトブラウザが立ち上がったら，
# 右側にある `New`＞`Julia 1.10.3` を選択すると
# 新規で空のノートブックが作成される．

# %% [markdown]
# ### Juliaの起動
# はじめに Terminal を`Ctrl+Alt+T` あるいは 「`Super` (Windowsキーのこと）＞検索窓で`terminal`と入力＞Terminalアイコン」
# で起動する．Terminalのプロンプトで
# ```
# $ julia
# ```
# と入力し，Enterを押す．
#
# Juliaが起動後，**Juliaのバージョンが v1.6.7 である**ことを確認してほしい．<br>
# （v1.9.3 では Jupyter Notebook で正常に動作しない．）
#
# <img src = "./RunJulia.png" width=70%>
#
# <!--
# 【注意】2023年度の全学計算機システムには v1.9.3 と v1.6.7 (LTS) の両方がインストールされている．
#  リモートデスクトップでは `$ julia` で v1.6.7 が起動するが，サテライト室の端末では v1.9.3が起動してしまう．
# -->

# %% [markdown]
# セルに`versioninfo()`を入力し，`Shift+Enter`を押す．

# %%
versioninfo()
# Out:
# Julia Version 1.6.7
# Commit 3b76b25b64 (2022-07-19 15:11 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: AMD Ryzen 9 5950X 16-Core Processor
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-11.0.1 (ORCJIT, generic)

# %% [markdown]
# ## Jupyter Notebook の操作メモ：[User Documentation](https://jupyter-notebook.readthedocs.io/en/latest/notebook.html)
# - Command mode: セルに対しコピーや移動などの操作を行うモード
#     - `Enter`: 選択セルに対して edit modeに入る
#     - `m`: セルを Markdown に変更
#     - `y`: セルを Code に変更
# - Edit mode: セルの内容を編集するモード
#     - `Esc`: command modeに変更

# %% [markdown]
# ## ノーブックファイルの保存
# ノートブックを開いた時点でノートブックファイルは`Untitled.ipynb`
# というファイル名で保存されている．
# <br>
# ファイル名を変更するには，上部に表示されているファイル名 (`Untitled.ipynb`)をクリックするか，
# `ファイル＞リネーム`を選択する．
# <br>
# レポートのファイル名は授業で説明があった通りに適切に設定する．
#
# ## HTMLファイルへの変換
# `File＞Download as＞HTML(.html)`と選択するとHTMLに変換されたノートブックがダウンロードされる．
